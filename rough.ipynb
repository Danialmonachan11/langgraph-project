# %%
def add_item(element, my_list=[]):
    my_list.append(element)
    return my_list

print(add_item(1))  # Output: [1]
print(add_item(2))  # Output: [1, 2]  <-- The '1' is still there!
print(add_item(3))  # Output: [1, 2, 3]
# Out:
# [1]
# [1, 2]
# [1, 2, 3]
